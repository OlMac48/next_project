# %% [markdown]
# # Проект: Обучение с учителем: качество модели

# %% [markdown]
# **Описание проекта**
#
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
#
# **Задачи проекта:**
# 1.	Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
# 2.	Нужно собрать данные по клиентам по следующим группам:
#  -	Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
#  -	Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
#  -	Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
#  - 	Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени    проводит на сайте.
#
# **План решения задач:**
# 1.	Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# 2.	В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# 3.	Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.
#
#
# **Описание данных**
#
# Для исследования предоставлены следующие данные:
#  - market_file.csv
#  - market_money.csv
#  - market_time.csv
#  - money.csv
#
#
# Файл -  market_file.csv - данные о поведении покупателя на сайте
#
#  - id - номер покупателя в корпоративной базе данных.
#  - Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
#  - Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
#  - Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
#  - Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
#  - Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
#  - Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
#  - Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
#  - Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
#  - Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
#  - Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
#  - Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
#  - Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
#
# Файл -  market_money.csv  - данными о выручке, которую получает магазин с покупателя
#
#  - id — номер покупателя в корпоративной базе данных.
#  - Период — название периода, во время которого зафиксирована выручка. Например,'текущий_месяц' или 'предыдущий_месяц'.
#  - Выручка — сумма выручки за период.
#
#
# Файл -  market_time.csv - данные о времени (в минутах), которое покупатель провёл на сайте в течение периода
#
#  - id — номер покупателя в корпоративной базе данных.
#  - Период — название периода, во время которого зафиксировано общее время.
#  - минут — значение времени, проведённого на сайте, в минутах.
#
# Файл -  money.csv - данные о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
#  - id — номер покупателя в корпоративной базе данных.
#  - Прибыль — значение прибыли.
#
#
#
# **План работы**
#
# 1. Загрузка и изучение данных.
# 2. Предобработка данных, проверка пропусков, дубликатов.
# 3. Исследовательский анализ данных . Изучение признаков.
# 4. Объединение данных из файлов market_file.csv, market_money.csv и market_time.csv.
# 5. Корреляционный анализ данных, взаимосвязи признаков.
# 6. Подготовка пайплайна для моделирования. Создадим и обучим четыре вида модели машинного обучения. Выбор лучшей
# 7. Оценка важности признаков для лучшей модели , график важности SHAP.
# 8. Сегментация покупателей на основе результатов моделирования и данных о прибыльности покупателей.
# 9. Выберем группы покупателей. Предложения по увеличению её покупательской активности.
# 10. Выводы проекта.

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# ### Подготовка окружения

# %%
# 
# !pip install --upgrade scikit-learn -q

# %%
#установка библиотек
#вынужден был поставить конкретную версию shap, с последней - вылетала ошибка
# !pip install shap==0.42.0 -q
# !pip install phik -q
# !pip install missingno -q
# !pip install matplotlib -q

# %%
#загрузка библиотек
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import sklearn
import phik
import shap
import missingno as msno

# %%
#модели
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
#загрузка библиотек и метрик
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import (train_test_split, 
                                     cross_val_score, 
                                     GridSearchCV)
from sklearn.preprocessing import (OneHotEncoder, 
                                   OrdinalEncoder, 
                                   LabelEncoder, 
                                   StandardScaler, 
                                   MinMaxScaler)
from sklearn.metrics import roc_auc_score

# %%
# задаем константы

RANDOM_STATE = 42
TEST_SIZE = 0.25

# %%
pd.options.mode.chained_assignment = None

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# ## Загрузка исходных файлов

# %%
#загрузка данных из файла "Данные о поведении покупателя на сайте"
#предварительно выяснили что в файле есть разделители
data_mfile = pd.read_csv('https://code.s3.yandex.net/datasets/market_file.csv')
#загрузка данных из файла "Данные о выручке магазина"
data_mmoney = pd.read_csv('https://code.s3.yandex.net/datasets/market_money.csv')
#загрузка данных из файла "Данные о времени покупателя на сайте»"
data_mtime = pd.read_csv('https://code.s3.yandex.net/datasets/market_time.csv')
#загрузка данных из файла "Данные о среднемесячной прибыли от покупателя»"
data_money = pd.read_csv('https://code.s3.yandex.net/datasets/money.csv', sep = ';', decimal = ',')

# %%
#для вывода информации о наборах данных создадим функцию - первые стоки датасета, основная информация, диаграмма пропусков
def firstdf(data_s, name_s, numb):
    if numb == 1:
        display(f'Таблица {name_s}:', data_s.head())
        display(f'Информация о таблице {name_s}: ')
        display(data_s.info())
        display(f'Дубликатов в таблице {name_s} ', data_s.duplicated().sum())
    elif numb == 2:   
        display(f'Таблица {name_s}:', data_s.head())
        display(f'Информация о таблице {name_s}: ')
        display(data_s.info())
        display(f'Дубликатов в таблице  {name_s} ', data_s.duplicated().sum())
        display(f'Диаграмма пропусков в таблице  {name_s}: ')
        msno.bar(data_s, color="dodgerblue", sort="ascending", fontsize=12, figsize=(7,5))
    elif numb == 3:   
        display(f'Перечень колонок таблицы {name_s}: ')
        for col in data_s.columns:
            print(col)
    elif numb == 4:   
        data_s.columns = data_s.columns.str.lower()
        display(data_s.info())
    else :
        display('Неверный параметр', numb)

# %%
firstdf(data_mfile, 'Данные о поведении покупателя на сайте', 2)
# Out:
# 'Таблица Данные о поведении покупателя на сайте:'
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
# ...

# %%
firstdf(data_mmoney, 'Данные о выручке магазина', 2)
# Out:
# 'Таблица Данные о выручке магазина:'
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6
# 'Информация о таблице Данные о выручке магазина: '
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
# None
# 'Дубликатов в таблице  Данные о выручке магазина '
# 0
# 'Диаграмма пропусков в таблице  Данные о выручке магазина: '

# %%
firstdf(data_mtime, 'Данные о времени покупателя на сайте', 2)
# Out:
# 'Таблица Данные о времени покупателя на сайте:'
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13
# 'Информация о таблице Данные о времени покупателя на сайте: '
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
# None
# 'Дубликатов в таблице  Данные о времени покупателя на сайте '
# 0
# 'Диаграмма пропусков в таблице  Данные о времени покупателя на сайте: '

# %%
firstdf(data_money, 'Данные о среднемесячной прибыли от покупателя', 2)
# Out:
# 'Таблица Данные о среднемесячной прибыли от покупателя:'
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21
# 'Информация о таблице Данные о среднемесячной прибыли от покупателя: '
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB
# None
# 'Дубликатов в таблице  Данные о среднемесячной прибыли от покупателя '
# 0
# 'Диаграмма пропусков в таблице  Данные о среднемесячной прибыли от покупателя: '

# %% [markdown]
# В таблицах пропусков и дубликатов нет. Поправим названия колонок.

# %%
data_mfile = data_mfile.rename(columns={'Покупательская активность':'покупательская_активность',
                                        'Тип сервиса':'тип_сервиса', 
                                        'Разрешить сообщать':'разрешить_сообщать'})

# %%
firstdf(data_mfile, 'Данные о поведении покупателя на сайте', 4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
firstdf(data_mmoney, 'Данные о выручке магазина', 4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
# None

# %%
firstdf(data_mtime, 'Данные о времени покупателя на сайте', 4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
# None

# %%
firstdf(data_money, 'Данные о среднемесячной прибыли от покупателя', 4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB
# None

# %% [markdown]
# **Вывод.**  Данные загружены. Названия столбцов исправлены. Пропусков и явных дубликатов не выявлено. Типы данных соответсвуют описанию.

# %% [markdown]
# ##  Предобработка данных, проверка пропусков, дубликатов.

# %% [markdown]
# Явных дубликатов не выявлено, выполним поиск неявных и исправим ошибки в значениях.

# %%
#для вывода значений категориальных столбцов создадим функцию
#параметры - дата фрейм, список столбцов, параметр задающий набор функционала 
def nextdf(data_s, name_s, numb):
    if numb == 1:
        for names in name_s:
            print(f'\033[1m {names} \033[0m \n')
#            data_s[names].value_counts()
            print(data_s[names].value_counts(),'\n')
    else :
        display('Неверный параметр', numb)

# %%
data_mfile.head(10)
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
# 5  215353                 Снизилась   стандартт                 да
# 6  215354                 Снизилась   стандартт                 да
# 7  215355                 Снизилась   стандартт                нет
# 8  215356                 Снизилась   стандартт                 да
# 9  215357                 Снизилась   стандартт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 3.4                     5           121               0.00
# ...

# %%
nextdf(data_mfile, {'покупательская_активность', 'тип_сервиса', 'разрешить_сообщать', 'популярная_категория'}, 1)
# Out:
#  покупательская_активность
#
# Прежний уровень    802
# Снизилась          498
# Name: покупательская_активность, dtype: int64
#
#  популярная_категория
#
# Товары для детей                        330
# Домашний текстиль                       251
# Косметика и аксесуары                   223
# Техника для красоты и здоровья          184
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: популярная_категория, dtype: int64
#
#  тип_сервиса
#
# стандарт     914
# премиум      376
# стандартт     10
# Name: тип_сервиса, dtype: int64
#
#  разрешить_сообщать
#
# да     962
# нет    338
# Name: разрешить_сообщать, dtype: int64

# %% [markdown]
# Исправим опечатки в колонке "тип_сервиса"

# %%
#исправим опечатки
data_mfile['тип_сервиса'] = data_mfile['тип_сервиса'].replace('стандартт', 'стандарт')
data_mfile['популярная_категория'] = data_mfile['популярная_категория'].replace('Косметика и аксесуары', 'Косметика и аксессуары')

# %%
nextdf(data_mfile, {'тип_сервиса', 'популярная_категория'}, 1)
# Out:
#  популярная_категория
#
# Товары для детей                        330
# Домашний текстиль                       251
# Косметика и аксессуары                  223
# Техника для красоты и здоровья          184
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: популярная_категория, dtype: int64
#
#  тип_сервиса
#
# стандарт    924
# премиум     376
# Name: тип_сервиса, dtype: int64

# %%
#повторно проверим дубликаты
print(f'Дубликатов в таблице  data_mfile ', data_mfile.duplicated().sum())
# Out:
# Дубликатов в таблице  data_mfile  0

# %%
nextdf(data_mmoney, {'период'}, 1)
# Out:
#  период
#
# текущий_месяц          1300
# предыдущий_месяц       1300
# препредыдущий_месяц    1300
# Name: период, dtype: int64

# %%
nextdf(data_mtime, {'период'}, 1)
# Out:
#  период
#
# текущий_месяц       1300
# предыдцщий_месяц    1300
# Name: период, dtype: int64

# %%
#исправим опечатки
data_mtime['период'] = data_mtime['период'].replace('предыдцщий_месяц', 'предыдущий_месяц')

# %%
data_mfile.describe().T
# Out:
#                                       count           mean         std  \
# id                                   1300.0  215997.500000  375.421985
# маркет_актив_6_мес                   1300.0       4.253769    1.014814
# маркет_актив_тек_мес                 1300.0       4.011538    0.696868
# длительность                         1300.0     601.898462  249.856289
# акционные_покупки                    1300.0       0.319808    0.249843
# средний_просмотр_категорий_за_визит  1300.0       3.270000    1.355350
# неоплаченные_продукты_штук_квартал   1300.0       2.840000    1.971451
# ошибка_сервиса                       1300.0       4.185385    1.955298
# страниц_за_визит                     1300.0       8.176923    3.978126
#
#                                           min        25%        50%  \
# id                                   215348.0  215672.75  215997.50
# маркет_актив_6_мес                        0.9       3.70       4.20
# ...

# %%
data_mmoney.describe().T
# Out:
#           count           mean          std       min        25%       50%  \
# id       3900.0  215997.500000   375.325686  215348.0  215672.75  215997.5
# выручка  3900.0    5025.696051  1777.704104       0.0    4590.15    4957.5
#
#                75%       max
# id       216322.25  216647.0
# выручка    5363.00  106862.2

# %%
data_mtime.describe().T
# Out:
#         count           mean         std       min        25%       50%  \
# id     2600.0  215997.500000  375.349754  215348.0  215672.75  215997.5
# минут  2600.0      13.336154    4.080198       4.0      10.00      13.0
#
#              75%       max
# id     216322.25  216647.0
# минут      16.00      23.0

# %%
data_money.describe().T
# Out:
#           count           mean         std        min        25%         50%  \
# id       1300.0  215997.500000  375.421985  215348.00  215672.75  215997.500
# прибыль  1300.0       3.996631    1.013722       0.86       3.30       4.045
#
#                75%        max
# id       216322.25  216647.00
# прибыль       4.67       7.43

# %% [markdown]
# Явных аномалий не замечено.
#
# **Вывод.** удалено 3 неявных дубликата. Явных дуюликатов не обнаружено. Аномальных значений не выявлено

# %% [markdown]
# ##  Исследовательский анализ данных

# %% [markdown]
# ###  Подготовка данных

# %% [markdown]
# Для анализа необходимо отобрать покупателей с активностью не менее трех месяцев. Найдем все исключения из данного условия.

# %%
nextdf(data_mmoney, {'выручка'}, 1)
# Out:
#  выручка
#
# 4729.0    8
# 5051.0    7
# 4952.0    7
# 0.0       6
# 4974.0    6
#          ..
# 4823.5    1
# 5776.0    1
# 5001.2    1
# 4146.6    1
# 4681.4    1
# Name: выручка, Length: 2776, dtype: int64

# %%
data_mmoney.loc[data_mmoney['выручка'] == 0]
# Out:
#         id               период  выручка
# 0   215348  препредыдущий_месяц      0.0
# 2   215348     предыдущий_месяц      0.0
# 28  215357  препредыдущий_месяц      0.0
# 29  215357     предыдущий_месяц      0.0
# 34  215359     предыдущий_месяц      0.0
# 35  215359  препредыдущий_месяц      0.0

# %% [markdown]
# Удалим записи по данным пользователям из таблицы

# %%
id_bad = [215348, 215357, 215359]
data_mfile_ok = data_mfile.query('id not in [215348, 215357, 215359]')
data_mmoney_ok = data_mmoney.query('id not in [215348, 215357, 215359]')
data_mtime_ok = data_mtime.query('id not in [215348, 215357, 215359]')
data_money_ok = data_money.query('id not in [215348, 215357, 215359]')
print(data_mfile_ok['id'].nunique())
print(data_mmoney_ok['id'].nunique())
print(data_mtime_ok['id'].nunique())
print(data_money_ok['id'].nunique())
# Out:
# 1297
# 1297
# 1297
# 1297

# %%
print(len(data_mfile_ok['id']))
print(len(data_mmoney_ok['id']))
print(len(data_mtime_ok['id']))
print(len(data_money_ok['id']))
# Out:
# 1297
# 3891
# 2594
# 1297

# %% [markdown]
# Оставили покупателей, которые обладают покупательской активностью в течение трех последних месяцев.

# %% [markdown]
# Целевой признак - **'покупательская активность'**.
#
# Необходимо собрать в один датасет показатели временные и финансовые.
#
# Предоставленные параметры относятся к числовым или категориальным, они разделены следующим образом:
#
#  - категориальные
#    - покупательская_активность,
#    - тип_сервиса,
#    - разрешить_сообщать,
#    - популярная_категория.
#  - числовые
#    - маркет_актив_6_мес,
#    - маркет_актив_тек_мес,
#    - длительность,
#    - акционные_покупки,
#    - средний_просмотр_категорий_за_визит,
#    - неоплаченные_продукты_штук_квартал,
#    - ошибка_сервиса,
#    - страниц_за_визит,
#    - выручка,
#    - минут.

# %% [markdown]
# Разделим данные по клиентам по группам:
#
#  - Признаки, которые описывают коммуникацию сотрудников компании с клиентом - это
#    - тип_сервиса,
#    - разрешить_сообщать,
#    - маркет_актив_6_мес,
#    - маркет_актив_тек_мес,
#    - длительность.
#
#  - Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто. Это
#    - популярная_категория,
#    - средний_просмотр_категорий_за_визит,
#    - неоплаченные_продукты_штук_квартал.
#
#  - Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине. Это значения
#    - выручка и разница или сумма этих значений за разные периоды.
#
#  - Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени  проводит на сайте. Это
#    - страниц_за_визит,
#    - ошибка_сервиса,
#    - количество минут, проведенных на сайте за разные периоды (соберем из период и минут).

# %% [markdown]
# ###  Изучим распределения признаков

# %%
data_mfile_ok['покупательская_активность'].value_counts()\
                                        .plot(style='-',title='Активность покупателей',\
                                          figsize=(7,3), kind='barh',color="dodgerblue", legend = False)
plt.xticks(rotation = 0);
plt.show();

# %%
data_mfile_ok['покупательская_активность'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# Прежний уровень    61.8%
# Снизилась          38.2%
# Name: покупательская_активность, dtype: object

# %% [markdown]
# Дисбаланс целевого признака диктует то, что в качестве метрик для моделей МО нужно выбирать метрики отличные от accuracy. Налицо дисбаланс классов. Будем выбирать из recall, precision, f1-мера, матрица ошибок.

# %%
data_mfile_ok.head(10)
# Out:
#         id покупательская_активность тип_сервиса разрешить_сообщать  \
# 1   215349                 Снизилась     премиум                 да
# 2   215350                 Снизилась    стандарт                нет
# 3   215351                 Снизилась    стандарт                 да
# 4   215352                 Снизилась    стандарт                нет
# 5   215353                 Снизилась    стандарт                 да
# 6   215354                 Снизилась    стандарт                 да
# 7   215355                 Снизилась    стандарт                нет
# 8   215356                 Снизилась    стандарт                 да
# 10  215358                 Снизилась    стандарт                 да
# 12  215360                 Снизилась     премиум                 да
#
#     маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 1                  4.4                     4           819               0.75
# ...

# %%
data_mfile_ok['популярная_категория'].value_counts()\
                                        .plot(style='-',title='Сравнение количества клиентов по типу категории товаров',\
                                          figsize=(7,3), kind='barh',color="dodgerblue", legend = False)
plt.xticks(rotation = 0);
plt.show();

# %%
data_mfile_ok['тип_сервиса'].value_counts()\
                                        .plot(style='-',title='Сравнение количества клиентов по типу сервиса',\
                                          figsize=(7,3), kind='barh',color="gold", legend = False)
plt.xticks(rotation = 0);
plt.show();

# %%
data_mfile_ok['тип_сервиса'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# стандарт    71.1%
# премиум     28.9%
# Name: тип_сервиса, dtype: object

# %%
data_mfile_ok['разрешить_сообщать'].value_counts()\
                                        .plot(style='-',title='Сравнение количества клиентов по типу согласия на получение предложений',\
                                          figsize=(7,3), kind='barh',color="dodgerblue", legend = False)
plt.xticks(rotation = 0);
plt.show();

# %%
data_mfile_ok['разрешить_сообщать'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# да     73.9%
# нет    26.1%
# Name: разрешить_сообщать, dtype: object

# %% [markdown]
# **Вывод** по категориальным признакам.
# 1. у 38% покупателей снизилась покупательская активность.
# 2. 71% покупателей устраивает стандартный сервис, 29 претендуют на премиум.
# 3. 74% не против получать дополнительные предложения.
# 4. Среди представленных шести категорий лидируют - Товары для детей, Домашний текстиль и Косметика и аксессуары.

# %%
#users_go.pivot_table(index='age', values='user_id', aggfunc=('count'))\
#                                        .sort_values('age', ascending=True)\
#                                        .plot(style='-',title='Количество пользователей сервиса по возрастам',\
#                                          figsize=(13,7), kind='bar',color="dodgerblue", legend = False)
#plt.xlabel('Возраст');
#plt.xticks(rotation = 0);
#plt.ylabel('Количество');
#plt.show();
data_mfile_ok['маркет_актив_6_мес'].value_counts()\
                                        .plot(style='-',title='Среднемесячные маркетинговые коммуникации с клиентом за 6 месяцев ',\
                                         figsize=(12,7), kind='bar',color="gold", legend = False)
plt.xticks(rotation = 60);
plt.show();

# %%
data_mfile_ok
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась    стандарт                нет
# 3     215351                 Снизилась    стандарт                 да
# 4     215352                 Снизилась    стандарт                нет
# 5     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 1                    4.4                     4           819
# ...

# %%
data_mfile_ok['маркет_актив_тек_мес'].value_counts()\
                                        .plot(style='-',title='Среднемесячные маркетинговые коммуникации с клиентом за текущий месяц ',\
                                         figsize=(7,5), kind='bar',color="dodgerblue", legend = False)
plt.xticks(rotation = 0);
plt.show();

# %% [markdown]
#  В текущем месяце клиенты получали 3-5 предложений. В среднем за месяц по данным за 6 месяцев чаще всего покупатели получали 4 предложения.

# %%
plt.figure(figsize = (7,5))
plt.hist(data_mfile_ok['длительность'],  bins=11, color = 'gold')
plt.title('Распределение клиентов по длительности регистрации');
plt.xlabel('Длительность регистрации');
plt.ylabel('Количество');
plt.show()

# %%
print(data_mfile_ok['длительность'])
# Out:
# 1        819
# 2        539
# 3        896
# 4       1064
# 5        762
#         ...
# 1295     318
# 1296     454
# 1297     586
# 1298     645
# 1299     906
# Name: длительность, Length: 1297, dtype: int64

# %% [markdown]
# График подтверждает то, что отобраны клиенты значения длительности регистрации которых больше 180 дней.

# %%
#по параметру "Акционные покупки" - среднемесячная доля покупок по акции от общего числа покупок за 6 месяцев
plt.figure(figsize = (7,5))
plt.hist(data_mfile_ok['акционные_покупки'], bins=11, color = 'dodgerblue')
plt.title('Распределение клиентов по доле акционных товаров в общем числе покупок за 6 месяцев');
plt.xlabel('Доля акционных товаров');
plt.ylabel('Количество');
plt.show()

# %% [markdown]
# Выявлено сегментирование клиентов на 2 сегмента - 1 - с долей акционных товаров в покупках до 40% и 2 - с долей акционных товаров в покупках от 85%.

# %%
data_mfile_ok
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась    стандарт                нет
# 3     215351                 Снизилась    стандарт                 да
# 4     215352                 Снизилась    стандарт                нет
# 5     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 1                    4.4                     4           819
# ...

# %%
#по параметру "Средний просмотр категорий за визит" - сколько в среднем категорий посмотрел покупатель за один
#визит в течении последнего месяца
plt.figure(figsize = (7,5))
plt.hist(data_mfile_ok['средний_просмотр_категорий_за_визит'], bins=11, color = 'gold')
plt.title('Распределение клиентов по кол-ву просмотренных категорий за визит всреднем за последний месяц');
plt.xlabel('Категорий за визит');
plt.ylabel('Количество');
plt.show()

# %%
data_mfile_ok['средний_просмотр_категорий_за_визит'].value_counts()\
                                        .plot(style='-',title='Распределение клиентов по кол-ву просмотренных категорий за визит всреднем за последний месяц',\
                                         figsize=(7,5), kind='bar',color="dodgerblue", legend = False)
plt.xticks(rotation = 0);
plt.show();

# %%
#по параметру "Страниц за визит" - сколько в среднем страниц посмотрел покупатель за один
#визит за последние 3 месяца
plt.figure(figsize = (7,5))
plt.hist(data_mfile_ok['страниц_за_визит'], color = 'dodgerblue')
plt.title('Распределение клиентов по кол-ву просмотренных страниц за визит всреднем за последние 3 месяца');
plt.xlabel('Страниц за визит');
plt.ylabel('Количество');
plt.show()

# %%
#ax = sns.boxplot(x=data_mfile_ok['страниц_за_визит'])

# %%
#по параметру "Неоплаченные продукты штук в квартал" - общее кол-во неоплаченных продуктов в корзине за последние 3 месяца
plt.figure(figsize = (7,5))
plt.hist(data_mfile_ok['неоплаченные_продукты_штук_квартал'], bins=11, color = 'gold')
plt.title('Распределение клиентов по общему числу неоплаченных продуктов в корзине за последние 3 месяца');
plt.xlabel('Неоплаченные продукты в корзине');
plt.ylabel('Количество');
plt.show()

# %% [markdown]
# В основном, по данным за последний квартал, клиенты оставляют от 0 до 5 штук товаров в корзине. Цель не ясна, возможно, пока не готовы принять решение. Можно обратить внимание заказчика на это - чтобы, например, простимулировать клиентов дополнительно.

# %%
#по параметру "Ошибка сервиса" - число сбоев во время посещения сайта покупателем
plt.figure(figsize = (7,5))
plt.hist(data_mfile_ok['ошибка_сервиса'], bins=10, color = 'dodgerblue')
plt.title('Распределение клиентов по числу сбоев во время посещения');
plt.xlabel('Число сбоев');
plt.ylabel('Количество');
plt.show()

# %% [markdown]
# Во время посещения сайта клиенты ощутили большое число сбоев - качество сервиса плохое.

# %%
#по параметру "Выручка" - сумма выручки за период
plt.figure(figsize = (7,5))
plt.hist(data_mmoney_ok['выручка'], bins=65, color = 'gold')
plt.title('Распределение ежемесячной выручки');
plt.xlabel('Величина выручки');
plt.ylabel('Количество');
plt.show()

# %%
data_mmoney_ok.describe().T
# Out:
#           count           mean          std       min       25%       50%  \
# id       3891.0  215998.986893   374.482249  215349.0  215675.0  215999.0
# выручка  3891.0    5033.718890  1768.471286    2758.7    4592.0    4959.0
#
#               75%       max
# id       216323.0  216647.0
# выручка    5363.2  106862.2

# %% [markdown]
# Проверим значения выручки, причину и число значений отличающихся от основной массы. Возможно это единичные значения.

# %%
print(data_mmoney_ok.query('выручка > 6000').value_counts().sum())
# Out:
# 310

# %%
print(data_mmoney_ok.query('выручка > 7000').value_counts().sum())
# Out:
# 35

# %%
print(data_mmoney_ok.query('выручка > 8000').value_counts().sum())
# Out:
# 1

# %%
#запомним эту строку - чтобы удалить из итогового датафрейма выброс
data_mmoney_ok.query('выручка > 8000')
# Out:
#         id         период   выручка
# 98  215380  текущий_месяц  106862.2

# %%
#ограничим распределение 
data_mmoney_ok1 = data_mmoney_ok.query('выручка < 8000')
plt.figure(figsize = (7,5))
plt.hist(data_mmoney_ok1['выручка'], bins=13, color = 'gold')
plt.title('Распределение ежемесячной выручки');
plt.xlabel('Величина выручки');
plt.ylabel('Количество');
plt.show()

# %%
# по параметру 'минут' - значению времени проведенному на сайте
plt.figure(figsize = (7,5))
plt.hist(data_mtime_ok['минут'], color = 'dodgerblue')
plt.title('Распределение клиентов по времени проведенному на сайте');
plt.xlabel('Время, мин');
plt.ylabel('Количество');
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
# Совет:
#
#
# - для гистограмм по выручке и минутам, стоит предварительно сделать группировку по "период" (у нас будет 3 графика по выручке и 2 по минутам), это разумно, ведь именно в таком виде мы используем их

# %%
data_mfile_ok[['длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', \
               'страниц_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса']]\
                .hist(figsize=(10, 15), color = 'dodgerblue')
plt.xticks(rotation = 0);
plt.show()

# %% [markdown]
# **Предварительный вывод.**
# 1. Клиент в среднем проводит на сайте 12-15 минут в месяц.
# 2. Клиент просматривает 5-10 страниц.
# 3. За указанное время он сталкивается с 3-5 сбоями.

# %% [markdown]
# ###  Графики с усами

# %%
#Построим графики с усами
fig, axes = plt.subplots(3, 3, figsize=(15,15));
plt.subplots_adjust(wspace=0.5, hspace=0.3)
sns.boxplot(data=data_mfile_ok, y='акционные_покупки', ax=axes[0, 0]).set (title='Доля акционнах товаров');
sns.boxplot(data=data_mfile_ok, y='средний_просмотр_категорий_за_визит', ax=axes[0, 1]).set (title='Категорий за визит');
sns.boxplot(data=data_mfile_ok, y='маркет_актив_6_мес', ax=axes[0, 2]).set (title='Маркетинг за 6 месяцев');
sns.boxplot(data=data_mfile_ok, y='неоплаченные_продукты_штук_квартал', ax=axes[1, 0]).set (title='Товаров в корзине');
sns.boxplot(data=data_mfile_ok, y='страниц_за_визит', ax=axes[1, 1]).set (title='Страниц за визит');
sns.boxplot(data=data_mfile_ok, y='ошибка_сервиса', ax=axes[1, 2]).set (title='Ошибки сервиса');
sns.boxplot(data=data_mfile_ok, y='длительность', ax=axes[2, 0]).set (title='Длительность регистрации');
sns.boxplot(data=data_mmoney_ok, y='выручка', ax=axes[2, 1]).set (title='Выручка, мес');
sns.boxplot(data=data_mtime_ok, y='минут', ax=axes[2, 2]).set (title='Время на сайте');

# %% [markdown]
# **Вывод:**
# 1. Клиент в среднем проводит 10-16 минут в месяц на сайте.
# 2. Клиент тратит в месяц 4500 - 5500 рублей.
# 3. В среднем клиент посещает 5-11 страниц в магазине.
# 4. За визит клиент изучает 2-4 категории за визит.
# 5. За визит клиент сталкивается с 3-6 ошибками сервиса.
# 6. Клиенту делается 3-5 доп предложений в месяц.
# 7. Основная часть клиентов зарегистрирована 400-800 дней.
# 8. У клиента 20-30% акционных товаров в покупках ( но гистограмма показала разделение на 2 группы).
# 9. У клиента остается неоплаченных вв корзине 1-4 товара.
#
#
# В результате, клиент скорее мало проводит время в магазине (либо сервис очень понятный), слишком большое количество ошибок при работе с сервисом, данные содержат выбросы.

# %% [markdown]
# ##  Объединение таблиц

# %% [markdown]
# В связи с тем, что нам нужно учитывать, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов, необходимо в итоговой таблице сделайте отдельный столбец для каждого периода.

# %% [markdown]
# ###  Подготовка таблиц

# %% [markdown]
# Указанные данные содержатся во втором и третьем файле, преобразуем их

# %%
data_mmoney_ok
# Out:
#           id               период  выручка
# 3     215349  препредыдущий_месяц   4472.0
# 4     215349        текущий_месяц   4971.6
# 5     215349     предыдущий_месяц   5216.0
# 6     215350  препредыдущий_месяц   4826.0
# 7     215350        текущий_месяц   5058.4
# ...      ...                  ...      ...
# 3895  216646  препредыдущий_месяц   4725.0
# 3896  216646     предыдущий_месяц   4923.0
# 3897  216647     предыдущий_месяц   4720.0
# 3898  216647  препредыдущий_месяц   5183.0
# 3899  216647        текущий_месяц   4448.3
#
# [3891 rows x 3 columns]

# %%
data_mmoney_ok_time = data_mmoney_ok.pivot_table(index='id', columns='период', values='выручка')
data_mmoney_ok_time
# Out:
# период  предыдущий_месяц  препредыдущий_месяц  текущий_месяц
# id
# 215349            5216.0               4472.0         4971.6
# 215350            5457.5               4826.0         5058.4
# 215351            6158.0               4793.0         6610.4
# 215352            5807.5               4594.0         5872.5
# 215353            4738.5               5124.0         5388.5
# ...                  ...                  ...            ...
# 216643            3664.0               4704.0         4741.7
# 216644            4729.0               5299.0         5353.0
# 216645            5160.0               5334.0         5139.2
# 216646            4923.0               4725.0         5224.6
# 216647            4720.0               5183.0         4448.3
#
# [1297 rows x 3 columns]

# %%
data_mtime_ok
# Out:
#           id            период  минут
# 2     215349     текущий_месяц     10
# 3     215349  предыдущий_месяц     12
# 4     215350     текущий_месяц     13
# 5     215350  предыдущий_месяц      8
# 6     215351     текущий_месяц     13
# ...      ...               ...    ...
# 2595  216645     текущий_месяц     18
# 2596  216646  предыдущий_месяц     18
# 2597  216646     текущий_месяц      7
# 2598  216647     текущий_месяц     10
# 2599  216647  предыдущий_месяц     15
#
# [2594 rows x 3 columns]

# %%
data_mtime_ok_time = data_mtime_ok.pivot_table(index='id', columns='период', values='минут')
data_mtime_ok_time
# Out:
# период  предыдущий_месяц  текущий_месяц
# id
# 215349                12             10
# 215350                 8             13
# 215351                11             13
# 215352                 8             11
# 215353                10             10
# ...                  ...            ...
# 216643                14              7
# 216644                12             11
# 216645                12             18
# 216646                18              7
# 216647                15             10
#
# [1297 rows x 2 columns]

# %% [markdown]
# ###  Объединение таблиц

# %%
data_m= data_mfile_ok.merge(data_mmoney_ok_time, on='id', how='left').rename(
    columns={'предыдущий_месяц':'выручка_пред', 'препредыдущий_месяц':'выручка_препред',
             'текущий_месяц':'выручка_тек'})

data_m
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215349                 Снизилась     премиум                 да
# 1     215350                 Снизилась    стандарт                нет
# 2     215351                 Снизилась    стандарт                 да
# 3     215352                 Снизилась    стандарт                нет
# 4     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1292  216643           Прежний уровень    стандарт                 да
# 1293  216644           Прежний уровень    стандарт                нет
# 1294  216645           Прежний уровень    стандарт                 да
# 1295  216646           Прежний уровень    стандарт                 да
# 1296  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    4.4                     4           819
# ...

# %%
data_m = data_m.merge(data_mtime_ok_time, on='id', how='left').rename(
    columns={'предыдущий_месяц':'время_пред', 'текущий_месяц':'время_тек'})
data_m
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215349                 Снизилась     премиум                 да
# 1     215350                 Снизилась    стандарт                нет
# 2     215351                 Снизилась    стандарт                 да
# 3     215352                 Снизилась    стандарт                нет
# 4     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1292  216643           Прежний уровень    стандарт                 да
# 1293  216644           Прежний уровень    стандарт                нет
# 1294  216645           Прежний уровень    стандарт                 да
# 1295  216646           Прежний уровень    стандарт                 да
# 1296  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    4.4                     4           819
# ...

# %%
#избавимся от выброса по выручке
data_m.loc[data_m['id']==215380]
# Out:
#         id покупательская_активность тип_сервиса разрешить_сообщать  \
# 29  215380                 Снизилась     премиум                нет
#
#     маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 29                 1.7                     4           637               0.94
#
#               популярная_категория  средний_просмотр_категорий_за_визит  \
# 29  Техника для красоты и здоровья                                    3
#
#     неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит  \
# 29                                   2               4                 7
#
#     выручка_пред  выручка_препред  выручка_тек  время_пред  время_тек
# 29        6077.0           5051.0     106862.2          12         14

# %%
data_m = data_m.loc[data_m['id']!=215380]

# %%
#проверим данные после объединения
firstdf(data_m, 'Объединенные данные о покупателях', 2)
# Out:
# 'Таблица Объединенные данные о покупателях:'
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
# 3  215352                 Снизилась    стандарт                нет
# 4  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
# ...

# %% [markdown]
# **Вывод** В итоге мы получили датасет "Объединенные данные о покупателях', 1296 записей.

# %% [markdown]
# ##  Корреляционный анализ

# %%
#избавимся от id
df_full = data_m
data_m = data_m.drop(['id'], axis = 1)

# %%
firstdf(data_m, 'Объединенные данные о покупателях', 3)
# Out:
# 'Перечень колонок таблицы Объединенные данные о покупателях: '
# покупательская_активность
# тип_сервиса
# разрешить_сообщать
# маркет_актив_6_мес
# маркет_актив_тек_мес
# длительность
# акционные_покупки
# популярная_категория
# средний_просмотр_категорий_за_визит
# неоплаченные_продукты_штук_квартал
# ошибка_сервиса
# страниц_за_визит
# выручка_пред
# выручка_препред
# выручка_тек
# время_пред
# время_тек

# %% [markdown]
# Целевой признак - "покупательская активность". Рассчитаем коэффициент корреляции Фи.

# %%
interval_columns = ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 
                    'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
                    'страниц_за_визит', 'выручка_пред', 'выручка_препред', 'выручка_тек', 'время_пред', 'время_тек']

sns.color_palette("Paired")
fig, ax = plt.subplots(figsize=(18, 8))
sns.heatmap(data_m.phik_matrix(interval_cols=interval_columns), annot=True, cmap='coolwarm',  fmt=".2f") #, mask=matrix2)
plt.xticks(rotation=80)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# Для целевого признака "покупательская активность" наибольшая корреляция установлена с признаками - "маркет актив 6 мес", "акционные покупки", "средний просмотр категорий за визит", "неоплаченные продукты штук квартал", "страниц за визит", "выручка_препред", "время_пред" и "время_тек".
#  Cильно связаны "выручка в текущем месяце" и "выручка в прошлом месяце", вероятно у них близкие значения.

# %%
firstdf(data_m, 'Объединенные данные о покупателях', 3)
# Out:
# 'Перечень колонок таблицы Объединенные данные о покупателях: '
# покупательская_активность
# тип_сервиса
# разрешить_сообщать
# маркет_актив_6_мес
# маркет_актив_тек_мес
# длительность
# акционные_покупки
# популярная_категория
# средний_просмотр_категорий_за_визит
# неоплаченные_продукты_штук_квартал
# ошибка_сервиса
# страниц_за_визит
# выручка_пред
# выручка_препред
# выручка_тек
# время_пред
# время_тек

# %%
#col_num = ['маркет_актив_6_мес', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'спо', 'жирность', 'белок']
col_cat = ['тип_сервиса', 'популярная_категория']
factor = {'маркет_актив_6_мес', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 
          'неоплаченные_продукты_штук_квартал', 'страниц_за_визит', 'выручка_препред', 'время_пред', 'время_тек'}

# %%
def scplots_cat(df, par1, par2, cat):
        v_palette =  {"dodgerblue", "gold", "red", "green"}
        fig, axes = plt.subplots(2, 3, figsize=(15,10));
        plt.subplots_adjust(wspace=0.3, hspace=0.3)
        plt.suptitle(f'Сравнение величины {par1} от {par2} в зависимости от категориальных признаков')
        sns.scatterplot(data=data_m, x=par1, y=par2, hue=cat[0], ax=axes[0, 0], palette=violin_palette);
        sns.scatterplot(data=df, x=par1, y=par2, hue=cat[1], ax=axes[0, 1], palette=violin_palette);
        sns.scatterplot(data=df, x=par1, y=par2, hue=cat[2], ax=axes[0, 2], palette=violin_palette);
        sns.scatterplot(data=df, x=par1, y=par2, hue=cat[3], ax=axes[1, 0], palette=violin_palette);
        sns.scatterplot(data=df, x=par1, y=par2, hue=cat[4], ax=axes[1, 1], palette=violin_palette);
        sns.scatterplot(data=df, x=par1, y=par2, hue=cat[5], ax=axes[1, 2], palette=violin_palette);

# %%
v_palette =  {"dodgerblue", "gold", "red", "green"}
fig, axes = plt.subplots(1, 2, figsize=(18,8));
plt.subplots_adjust(wspace=0.3, hspace=0.3)
sns.scatterplot(data=data_m, x='выручка_препред', y='маркет_актив_6_мес',
                hue='покупательская_активность', ax=axes[0], palette=v_palette) \
                .set(title='Зависимость выручки за период двухмесячной давности \n от количества \
маркетинговых коммуникаций с клиентом за полгода')
axes[0].legend(loc='lower center', bbox_to_anchor=(0.7, -0.2), shadow=True)

sns.scatterplot(data=data_m, x='страниц_за_визит', y='акционные_покупки', hue='покупательская_активность',
                ax=axes[1], palette=v_palette).set(title='Зависимость количества просмотренных \
страниц за визит \n от доли акционных покупок')

axes[1].legend(loc='lower center', bbox_to_anchor=(0.7, -0.2), shadow=True)
plt.show()

# %% [markdown]
# С ростом среднемесячной маркетинговой активности растет выручка. Сообщения об акциях работают.
# Покупатели со сниженным уровнем покупательской активности меньше просматривают страниц и меньше приносят выручки.
# Для покупателей с прежним уровнем активности характерна низкая доля акционных товаров в закупках.

# %%
fig, axes = plt.subplots(1, 2, figsize=(17,8));
plt.subplots_adjust(wspace=0.3, hspace=0.3)

sns.scatterplot(data=data_m, x='время_пред', y='страниц_за_визит',
                hue='покупательская_активность', ax=axes[0], palette=v_palette) \
                .set(title='Зависимость времени, проведенного на сайте  \n от количества просмотренных страниц \
в разрезе покупательской активности')
axes[0].legend(loc='lower center', bbox_to_anchor=(0.7, -0.2), shadow=True)

sns.scatterplot(data=data_m, x='время_пред', y='страниц_за_визит', hue='тип_сервиса',
                ax=axes[1], palette=v_palette)\
                .set(title='Зависимость времени, проведенного на сайте  \n от количества просмотренных страниц \
в разрезе типа сервиса')
axes[1].legend(loc='lower center', bbox_to_anchor=(0.7, -0.2), shadow=True)
plt.show()

# %%
sns.scatterplot(data=data_m, x='время_пред', y='страниц_за_визит', hue='популярная_категория',
               palette=v_palette)\
                .set(title='Зависимость времени, проведенного на сайте  \n от количества просмотренных страниц \
в разрезе популярной категории');
plt.legend(bbox_to_anchor=(1, 0.6), shadow=True);

# %% [markdown]
# Обнаружена зависимость между снижением покупательской активности временем просмотра сайта и количеством страниц просмотренных на сайте. Чем меньше величина времени и количества просмотренных страниц - тем менбьше покупательская активность.
# В то же время есть клиенты, которые успевают за пять минут просмотреть 8 страниц.
# Зависимости от типа сервиса и категории товара на время и кол-во просмотренных страниц не выявлено.

# %%
pd.options.mode.chained_assignment = None

# %%
# сравним зависимость выручки за период двухмесячной давности от доли акционных покупок в разрезе группы товаров
v_palette =  {"dodgerblue", "gold", "red", "green"}
sns.set_palette(v_palette)
plt.subplots_adjust(wspace=0.2, hspace=0.4)

sns.relplot(data=data_m, x='выручка_пред', y='акционные_покупки',  kind='scatter',
            col='популярная_категория', col_wrap=3, alpha=0.6)
plt.show();

# %% [markdown]
# По акции чаще покупают детские товары и домашний текстиль, меньше всего- мелкую бытовую технику.

# %% [markdown]
# **Вывод**
# На эпокупательскую_активность" оказывают влияние признаки описывающие поведение клиента  "акционные покупки", "средний просмотр категорий за визит", "неоплаченные продукты штук квартал", "страниц за визит", "выручка_препред", "время_пред" и "время_тек". Из признаков , описывающих коммуникацию  - "маркет актив 6 мес".  Мультиколлинеарности в данных не отмечено - нет высокой доли зависимости между параметрами. Замечено, что сильно связаны "выручка в текущем месяце" и "выручка в прошлом месяце".

# %%
# сравним зависимость выручки за период двухмесячной давности от доли акционных покупок в разрезе группы товаров
v_palette =  {"dodgerblue", "gold", "red", "green"}
sns.set_palette(v_palette)
plt.subplots_adjust(wspace=0.2, hspace=0.4)

sns.relplot(data=data_m, x='выручка_пред', y='акционные_покупки',  kind='scatter',
            col='популярная_категория', col_wrap=3, alpha=0.6)
plt.show();

# %%
df_full
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215349                 Снизилась     премиум                 да
# 1     215350                 Снизилась    стандарт                нет
# 2     215351                 Снизилась    стандарт                 да
# 3     215352                 Снизилась    стандарт                нет
# 4     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1292  216643           Прежний уровень    стандарт                 да
# 1293  216644           Прежний уровень    стандарт                нет
# 1294  216645           Прежний уровень    стандарт                 да
# 1295  216646           Прежний уровень    стандарт                 да
# 1296  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    4.4                     4           819
# ...

# %%
sns.scatterplot(data=data_m, x='выручка_тек', y='выручка_пред', hue='покупательская_активность',
                 palette=v_palette) \
                .set(title='Зависимость между текущей выручкой и предыдущей в разрезе покупательской активности ')
plt.legend(bbox_to_anchor=(1.3, 0.6), shadow=True);
plt.show();

# %% [markdown]
# Действительно интересная картина получается, есть рост выручки от предыдущего месяца, но в тоже время есть в зоне высокой выручки клиенты со сниженной покупательской активностью. Может быть причина в росте цен?

# %%
sns.scatterplot(data=df_full, x='id', y='акционные_покупки', hue='покупательская_активность',
                 palette=v_palette) \
                .set(title='Зависимость между id  и акционными покупками в разрезе покупательской активности ')
plt.legend(bbox_to_anchor=(1.3, 0.6), shadow=True);
plt.show();

# %% [markdown]
# Пользователи которые зарегистрировались позднее имеют активность на прежнем уровне, не снижающуюся. Был период в который покупок по акции было мало (не выше 0,4 доля). Вероятно, была земечена потеря клиентов и акции возобновились. Это при условии, что id формируются последовательно.

# %% [markdown]
# ##  Использование пайплайнов

# %% [markdown]
# ### Построение модели. Подготовка данных

# %% [markdown]
# Необходимо применить все изученные модели, для этого используем пайплайны.
#
# Четыре модели машинного обучения создадим и проверим с помощью пайплайнов для решения задачи.
#  KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression() и SVC().
#
# Создадим пайплайн, состоящий из этапов подготовки категориальных и количественных данных, обучения моделей, оценки их качества с помощью метрики ROC_AUC.
#
# Метрика ROC_AUC является наиболее общей и независимой оценкой эффективности модели. Она равна площади под кривой ROC, которая, в свою очередь, показывает зависимость между TPR и FRP — промежуточными метриками, которые оценивают число верно классифицированных объектов класса 1 и неверно классифицированных объектов класса 0.
#
# Идеальная модель имеет величину ROC_AUC равную 1.
#
#
#
# метрики F1 и ROC-AUC - это два разных способа оценки качества моделей машинного обучения, и они измеряют разные аспекты модели. Вот их основные отличия:
#
# 1. F1-мера (F1 Score): Измеряет точность и полноту модели. Эта метрика помогает оценить способность модели правильно классифицировать положительные и отрицательные примеры. F1-мера является хорошим выбором, когда у нас есть дисбаланс классов.
#
# 2. ROC-AUC (Receiver Operating Characteristic - Area Under the Curve): Оценивает способность модели различать между классами. Он измеряет площадь под ROC-кривой, которая показывает отношение между долей верно классифицированных положительных и долей ложноположительных результатов при изменении порогового значения.
#
# **Сфера применения:**
#
# 1. F1-мера: Часто используется в задачах с несбалансированными классами, таких как поиск аномалий, обнаружение мошенничества, медицинские диагнозы и другие задачи, где важна точность классификации положительных примеров.
#
# 2. ROC-AUC: Чаще используется в задачах бинарной классификации для оценки способности модели разделять классы, независимо от баланса классов.
#
# **Зависимость от порога:**
#
# 1. F1-мера: Чувствительна к выбору порогового значения для классификации.
#
# 2. ROC-AUC: Не зависит от конкретного порогового значения. Оценивает качество модели на всех возможных пороговых значениях и учитывает весь спектр чувствительности и специфичности.
#
# В зависимости от конкретной задачи и целей оценки модели, ты можешь выбирать между этими метриками. Если тебе важна способность модели правильно классифицировать положительные и отрицательные примеры, то F1-мера может быть предпочтительной. Если твоя задача связана с разделением классов, то ROC-AUC может быть более подходящей метрикой.

# %%
# разделение на выборки

X_train, X_test, y_train, y_test = train_test_split(
    data_m.drop(
        ['покупательская_активность'],axis=1),
    data_m['покупательская_активность'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = data_m['покупательская_активность']
)

# %%
#оценим размеры выборок 
X_train.shape
# Out:
# (972, 16)

# %%
 X_test.shape
# Out:
# (324, 16)

# %%
firstdf(data_m, 'Объединенные данные о покупателях', 3)
# Out:
# 'Перечень колонок таблицы Объединенные данные о покупателях: '
# покупательская_активность
# тип_сервиса
# разрешить_сообщать
# маркет_актив_6_мес
# маркет_актив_тек_мес
# длительность
# акционные_покупки
# популярная_категория
# средний_просмотр_категорий_за_визит
# неоплаченные_продукты_штук_квартал
# ошибка_сервиса
# страниц_за_визит
# выручка_пред
# выручка_препред
# выручка_тек
# время_пред
# время_тек

# %%
#списки признаков

ohe_columns = ['разрешить_сообщать', 'популярная_категория']

ord_columns = ['тип_сервиса']

num_columns = ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
               'акционные_покупки', 'средний_просмотр_категорий_за_визит',
               'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
               'страниц_за_визит', 'выручка_пред', 'выручка_препред',
              'выручка_тек', 'время_пред', 'время_тек']

# %%
#пайплайн для подготовки данных

ohe_pipe = Pipeline([('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))])

ord_pipe = Pipeline([('ord', OrdinalEncoder(categories=[
    ['стандарт', 'премиум'],
 ], handle_unknown = 'use_encoded_value', 
    unknown_value = np.nan
))])


data_preprocessor = ColumnTransformer([
    ('ohe', ohe_pipe, ohe_columns),
    ('ord', ord_pipe, ord_columns),
    ('num', [StandardScaler(), MinMaxScaler()], num_columns)
    ], 
    remainder='passthrough'
)

# создаём итоговый пайплайн

pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# ### Поиск оптимальной модели

# %%
# задаем параметры перебора моделей и их гиперпараметров

param_grid = [
    
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 6),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
     
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1,5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    {
        'models': [SVC(random_state=RANDOM_STATE)],
        'models__kernel': ['rbf','sigmoid', 'poly'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },
]

# %%
#
label_enc = LabelEncoder()

y_train_tf = label_enc.fit_transform(y_train)
y_test_tf = label_enc.transform(y_test)

pred_classes = [0, 1]

#print(label_enc.classes_)
print(pred_classes)
print(label_enc.inverse_transform(pred_classes))
# Out:
# [0, 1]
# ['Прежний уровень' 'Снизилась']

# %% [markdown]
# Используем GridSearch для подбора параметров

# %%
# %%time
grid = GridSearchCV(
    pipe_final, 
    param_grid=param_grid, 
    cv=5,
    scoring='roc_auc', 
    n_jobs=-1
)
grid.fit(X_train, y_train_tf)
print('Лучшая модель и её параметры:\n\n', grid.best_estimator_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['разрешить_сообщать',
#                                                    'популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('ord',
#                                                                    OrdinalEncoder(categories=[['стандарт',
# ...

# %%
# итоги проверки моделей

model_rank = pd.DataFrame(grid.cv_results_)
display(model_rank[
    ['rank_test_score', 'param_models', 'mean_test_score','params']
].sort_values('rank_test_score'))
# Out:
#     rank_test_score                                       param_models  \
# 57                1                               SVC(random_state=42)
# 58                2                               SVC(random_state=42)
# 46                3  LogisticRegression(penalty='l1', random_state=...
# 49                4  LogisticRegression(penalty='l1', random_state=...
# 52                5  LogisticRegression(penalty='l1', random_state=...
# ..              ...                                                ...
# 5                62            DecisionTreeClassifier(random_state=42)
# 4                62            DecisionTreeClassifier(random_state=42)
# 3                62            DecisionTreeClassifier(random_state=42)
# 61               65                               SVC(random_state=42)
# 62               66                               SVC(random_state=42)
#
#     mean_test_score                                             params
# ...

# %% [markdown]
# **Вывод**
# Лучший результат метрики ROC_AUC(0.908) получен на модели опорных векторов. {'models': SVC(random_state=42), 'models__kernel': 'rbf', 'preprocessor__num': StandardScaler()}.
# Для предсказания типа активности будем использовать данную модель.

# %%
#проверим работу модели на тестовой выборке
#рассчитаем прогноз на тестовых данных
y_pred = grid.best_estimator_.predict(X_test)
preds = roc_auc_score(y_test_tf, y_pred)
print(f'Метрика ROC_AUC на тестовой выборке : {preds}')
# Out:
# Метрика ROC_AUC на тестовой выборке : 0.8859361727945638

# %%
# инициализация модели

#model_best = SVC(random_state=RANDOM_STATE, probability=True)


# объявляем кодировщики

#encoder_bm = OneHotEncoder(drop='first', sparse_output=False)
#ord_bm = OrdinalEncoder(categories=[
#                        ['стандарт', 'премиум'],
#                        ], handle_unknown = 'use_encoded_value', 
#                        unknown_value = np.nan)
#
#scaler_bm = StandardScaler()
#label_bm = LabelEncoder()


# кодирование

#X_train_ohe_bm = encoder_bm.fit_transform(X_train[ohe_columns])
#X_test_ohe_bm = encoder_bm.transform(X_test[ohe_columns])
#encoder_col_names = encoder_bm.get_feature_names_out()

#X_train_ord_bm = ord_bm.fit_transform(X_train[ord_columns])
#X_test_ord_bm = ord_bm.transform(X_test[ord_columns])

#y_train = label_bm.fit_transform(y_train)
#y_test = label_bm.transform(y_test)
#print(label_bm.classes_)


# проверка

#encoder_col_names

# %%
# Стандартизация

#scaler_bm.fit(X_train[num_columns])
#X_train_scaled_bm = scaler_bm.transform(X_train[num_columns])

#X_test_scaled_bm = scaler_bm.transform(X_test[num_columns])

# %%
# сбор преобразованныз данных, обучение модели

#X_train_ohe_bm = pd.DataFrame(X_train_ohe_bm, columns=encoder_col_names)
#X_test_ohe_bm = pd.DataFrame(X_test_ohe_bm, columns=encoder_col_names)

#X_train_ord_bm = pd.DataFrame(X_train_ord_bm, columns=ord_columns)
#X_test_ord_bm = pd.DataFrame(X_test_ord_bm, columns=ord_columns)

#X_train_scaled_bm = pd.DataFrame(X_train_scaled_bm, columns=num_columns)
#X_test_scaled_bm = pd.DataFrame(X_test_scaled_bm, columns=num_columns)

#X_train_bm = pd.concat([X_train_ohe_bm, X_train_ord_bm, X_train_scaled_bm], axis=1)
#X_test_bm = pd.concat([X_test_ohe_bm, X_test_ord_bm, X_test_scaled_bm], axis=1)

#model_best.fit(X_train_bm, y_train)

# %% [markdown]
# ## Анализ важности признаков

# %%
feature_names=grid.best_estimator_.named_steps['preprocessor'].get_feature_names_out()
X_train_transformed = grid.best_estimator_.named_steps['preprocessor'].fit_transform(X_train)
X_test_transformed = grid.best_estimator_.named_steps['preprocessor'].fit_transform(X_test)

explainer = shap.Explainer(grid.best_estimator_.named_steps['models'].predict, X_train_transformed)
explainer.feature_names=feature_names
shap_values = explainer(X_train_transformed)
shap.plots.bar(shap_values, max_display=21)
# Out:
# Permutation explainer: 973it [11:44,  1.37it/s]

# %%
# используем визуализацию с помощью shap в соотвествии с заданием

#explainer = shap.Explainer(model_best.predict_proba, X_test_bm)
#explainer = shap.Explainer(grid.best_estimator_.predict, X_train)
#shap_values = explainer(X_test_bm)
#shap_values = explainer(X_test)

# %% [markdown]
# Наибольший эффект на модель оказывает признак  - "cтраниц_за_визит" - среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца ,
# чуть меньше  - "время_пред" и  - "время_тек" - время проведенное на сайте за предыдущий и текущий месяц.
#
# Далее идут признаки "акционные_покупки" - среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев и "средний_просмотр_категорий_за_визит" - сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
#
# Еще к значимым признакам можно отнести "выручка_препред" - выручка за препредыдущий месяц, "неоплаченные_продукты_штук_квартал" - общее число неоплаченных товаров в корзине за последние 3 месяца, "маркет_актив_6_мес" -  среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев.
#
# Все остальные признаки вносят менее значимый вклад в принятие решения моделью.
# Можно видеть, что все значимые признаки объединяет одно - они описывают время и эффективность взаимодействия с сайтом и продуктами.

# %%
#график со значениями

#shap.plots.beeswarm(shap_values[:, :, 1], max_display=9)
shap.plots.beeswarm(shap_values, max_display=9)

# %% [markdown]
# Значимость признаков сверху в низ.
#
# Класс 0 - это "покупательская_активность" Целевой признак принял значение не изменилась.
# Класс 1 - "покупательская_активность" снизилась".
#
# Высокие значения "страниц_за_визит" и "время_пред", "время_тек"(проведенного на сайте времени)  уменьшают вероятность отнесения клиента к категории - "Покупательская_активнось" снизилась.
#
# Для признаков "акционные_покупки" и "неоплаченные_продукты_штук_квартал" ситуация обратная - чем выше значение этих параметров, тем больше вероятность, что клиент станет меньше покупать в интернет-магазине.

# %% [markdown]
# Построим график Водопада - показывает влияние каждого признака на изменение прогноза относительно базового значения

# %%
shap.plots.waterfall(shap_values[15]) 
y_train_tf[15]
# Out:
# 1

# %% [markdown]
# Визуализирована вероятность получения первого класса для строки 130.
# Целевой признак "покупательская_активность" принял значение - "1", тоесть активность снизилась - график подтверждает: у клиента снизилось количество просмотренных страниц за визит, время, проведенное за сайте за два месяца, снизилась выручка от клиента между периодами двухмесячной давности и месячной давности.

# %%
shap.plots.waterfall(shap_values[130]) 
y_train_tf[130]
# Out:
# 0

# %% [markdown]
# Целевой признак "покупательская_активность" принял значение - "0", тоесть активность не изменилась - график подтверждает: у клиента увеличилось количество просмотренных просмотренных категорий, уменьшилось количество купленных товаров по акции.

# %% [markdown]
# **Вывод:**
# Сформирована модель для показателя "покупательская_активность" с помощью метода опорных векторов.
# Эффективность модели по метрике ROC_AUC составляет 0.908.
# Значения параметров для модели значимые - "страниц_за_визит" - кол-во просмотренных страниц за визит и "время_пред", "время_тек"(проведенного на сайте времени за предыдущий и текущий месяцы) , "акционные_покупки"- число товаров купленных по акции, "средний_просмотр_категорий_за_визит" следующие по значимости, затем идут "неоплаченные_покупки_шт_в_квартал", "маркет_актив_6_мес" - маркетинговая активность за 6 месяцев, "выручка_предпред" - выручка за препредыдущий месяц.
#
# Ранее выяснено, что среднее время на сайте - 12-15 минут, за это время клиент отсматривает 7-10 страниц.
# Для решения поставленной задачи необходимо увеличивать время проведенное на сайте и число просматриваемых страниц

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# ###  Cегментация

# %% [markdown]
# Используем результаты моделирования и данные о прибыльности покупателей

# %%
firstdf(data_money_ok, 'Данные о среднемесячной прибыли от покупателя', 1)
# Out:
# 'Таблица Данные о среднемесячной прибыли от покупателя:'
#        id  прибыль
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21
# 5  215353     3.95
# 'Информация о таблице Данные о среднемесячной прибыли от покупателя: '
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1297 entries, 1 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1297 non-null   int64
#  1   прибыль  1297 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 30.4 KB
# None
# 'Дубликатов в таблице Данные о среднемесячной прибыли от покупателя '
# 0

# %%
#объединим итоговый дата фрейм с данными о прибыли
data_m_ok = df_full.merge(data_money_ok, on='id', how='left')
firstdf(data_m_ok, 'Данные о покупателях с прибылью', 2)
# Out:
# 'Таблица Данные о покупателях с прибылью:'
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
# 3  215352                 Снизилась    стандарт                нет
# 4  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
# ...

# %%
plt.figure(figsize = (7,5))
plt.hist(data_m_ok['прибыль'],  bins=11, color = 'dodgerblue')
plt.title('Распределение прибыли клиентов');
plt.xlabel('Величина прибыли');
plt.ylabel('Количество');
plt.show()

# %%
#поверим есть корелляция между прибылью и другими параметрами
interval_col = ['id', 'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 
                    'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
                    'страниц_за_визит', 'выручка_пред', 'выручка_препред', 'выручка_тек', 'время_пред', 'время_тек', 'прибыль']

sns.color_palette("Paired")
fig, ax = plt.subplots(figsize=(18, 8))
sns.heatmap(data_m_ok.phik_matrix(interval_cols=interval_col), annot=True, cmap='coolwarm',  fmt=".2f") 
plt.xticks(rotation=80)
plt.yticks(rotation=0)
plt.show()

# %%
data_m_ok.phik_matrix(interval_cols = interval_col)['прибыль'].sort_values(ascending=False)
# Out:
# прибыль                                1.000000
# выручка_препред                        0.159543
# выручка_пред                           0.132826
# маркет_актив_тек_мес                   0.095359
# выручка_тек                            0.090209
# id                                     0.084901
# ошибка_сервиса                         0.081366
# популярная_категория                   0.069684
# разрешить_сообщать                     0.034982
# средний_просмотр_категорий_за_визит    0.021214
# длительность                           0.000000
# акционные_покупки                      0.000000
# покупательская_активность              0.000000
# неоплаченные_продукты_штук_квартал     0.000000
# страниц_за_визит                       0.000000
# маркет_актив_6_мес                     0.000000
# тип_сервиса                            0.000000
# время_пред                             0.000000
# время_тек                              0.000000
# Name: прибыль, dtype: float64

# %% [markdown]
# Параметр нормально распределен, есть небольшая корреляция между "прибыль" и "выручка_пред" и "выручка_препред" - выручка за прошлый и позапрошлый месячный периоды.

# %%
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})
v_palette =  {"dodgerblue", "gold", "red", "green"}
sns.set_palette(v_palette)
sns.violinplot(x="прибыль", y="популярная_категория", data=data_m_ok, orient='h');
sns.swarmplot(x="прибыль", y="популярная_категория", data=data_m_ok,  alpha=0.6, color='black', size=3)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(17,8));
plt.subplots_adjust(wspace=0.2, hspace=0.3)

plt.suptitle('Сравнение зависимости прибыли от величины выручки за разные месяцы')

sns.scatterplot(data=data_m_ok, x='выручка_препред', y='прибыль',
                hue='покупательская_активность', ax=axes[0])
axes[0].legend(loc='upper right', bbox_to_anchor=(0.7, -0.1), shadow=True)
sns.scatterplot(data=data_m_ok, x='выручка_пред', y='прибыль',
                hue='покупательская_активность', ax=axes[1])
axes[1].legend(loc='upper right', bbox_to_anchor=(0.7, -0.1), shadow=True)
plt.show()

# %% [markdown]
# Визуально корреляция не видна.

# %% [markdown]
# ###  Выбор группы покупателей

# %% [markdown]
# Выделим покупателей, которые покупают технику по акции. Анализ данных клиентов интересен тк акционные покупки отрицательно воздействуют на прокупательскую активность,

# %%
#посмотрим категории
nextdf(data_m_ok, {'популярная_категория'}, 1)
# Out:
#  популярная_категория
#
# Товары для детей                        329
# Домашний текстиль                       250
# Косметика и аксессуары                  223
# Техника для красоты и здоровья          182
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: популярная_категория, dtype: int64

# %%
#сформируем датафрейм из данных о покупателях техники по акции
df_tech_sale = data_m_ok.query('популярная_категория in ["Мелкая бытовая техника и электроника", \
                                    "Техника для красоты и здоровья"] and акционные_покупки > 0.6')

# %%
firstdf(df_tech_sale, 'Данные о покупателях техники по акции', 2)
# Out:
# 'Таблица Данные о покупателях техники по акции:'
#          id покупательская_активность тип_сервиса разрешить_сообщать  \
# 14   215365                 Снизилась    стандарт                 да
# 30   215382                 Снизилась    стандарт                 да
# 41   215393                 Снизилась    стандарт                нет
# 69   215421                 Снизилась     премиум                нет
# 115  215467                 Снизилась    стандарт                 да
#
#      маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 14                  3.9                     4           167
# 30                  4.6                     4           330
# 41                  4.6                     4           169
# 69                  4.0                     5           523
# 115                 4.4                     4           503
#
#      акционные_покупки                  популярная_категория  \
# 14                0.95        Техника для красоты и здоровья
# ...

# %%
df_tech_sale = df_tech_sale.drop('id', axis=1)

# %%
sns.color_palette("Paired")
fig, ax = plt.subplots(figsize=(18, 8))
sns.heatmap(df_tech_sale.phik_matrix(interval_cols=interval_col), annot=True, cmap='coolwarm',  fmt=".2f") 
plt.xticks(rotation=80)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# На "покупательскаю_активность" покупателей техники со скидкой больше всего оказывают влияние следующие параметры:
#  - "страниц_за_визит",
#  - "выручка_препред",
#  - "время_пред",
#  - "время_тек",
#  - "ошибка_сервиса"

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9));
plt.subplots_adjust(wspace=0.2, hspace=0.3)

plt.suptitle('Сравнение выручки за текущий месяц от некоторых параметров в разрезе покупательской активности')

sns.scatterplot(data=df_tech_sale, x='выручка_тек', y='страниц_за_визит',
                hue='покупательская_активность', ax=axes[0, 0])
axes[0, 0].legend(loc='lower left', bbox_to_anchor=(0.6, -0.3), shadow=True)

sns.scatterplot(data=df_tech_sale, x='выручка_тек', y='выручка_препред',
                hue='покупательская_активность', ax=axes[0, 1])
axes[0, 1].legend(loc='lower left', bbox_to_anchor=(0.6, -0.3), shadow=True)

sns.scatterplot(data=df_tech_sale, x='выручка_тек', y='время_пред',
                hue='покупательская_активность', ax=axes[1, 0])
axes[1, 0].legend(loc='lower left', bbox_to_anchor=(0.6, -0.3), shadow=True)


sns.scatterplot(data=df_tech_sale, x='выручка_тек', y='время_тек',
                hue='покупательская_активность', ax=axes[1, 1])
axes[1, 1].legend(loc='lower left', bbox_to_anchor=(0.6, -0.3), shadow=True)

plt.show()

# %%
sns.scatterplot(data=df_tech_sale, x='выручка_тек', y='ошибка_сервиса', hue='покупательская_активность' )\
                .set(title='Сравнение выручки за текущий месяц от ошибка_сервиса в разрезе покупательской активности');
plt.legend(bbox_to_anchor=(1.3, 0.6), shadow=True);

# %% [markdown]
# ###  Вывод о сегментах

# %% [markdown]
# У покупателей данного сегмента покупательская активность заметно не изменилась (осталась в прежних пропорциях), они в основном проводили на сайте не более 14 минут.
# У тех покупателей у которых активность снизилась выручка была не более 4800-5000. Те же, у кого активность осталась на прежнем уровне выручка была более 4800.
# Также для данной группы характерно, что у покупателей со снизившейся активностью время проведенное на сайте в предыдущий месяц было не более 12 минут, а у тех у кого активность осталась на прежнем уровне время на сайте было более 14 минут, в текущем месяце в общей массе в когорте в среднем время на сайте стало не более 14 минут. И выручка за текущий месяц выросла в среднем в когорте.

# %% [markdown]
# **Предложения:**
#
#     1. Необходимо улучшать качество сервиса - в предоставленных данных выявлено большое количество "ошибок_сайта".
#
#     2. Необходимо улучшать информационное наполнение сайта, делать перекрестную рекламу - клиенты мало проводят времени на сайте, мало посещают страниц.
#
#     3. Наличие неоплаченных товаров в корзине дает право говорить о возможности увеличения маркетинговой активности и проведению дополнительных акций.

# %% [markdown]
# ##  Общий вывод

# %% [markdown]
# В данной работе на соснове данных о продажах интернет-магазина "В один клик" (товары для детей, дома, мелкой бытовой техники и продуктов) нам было поручено разработать решение , которое позволит персонализировать предложения постоянным клиентам , чтобы увеличить их покупательскую активность.
#
# Заказчик передал информацию о поведении покупателя на сайте с информацией о покупках не менее 3 месяцев. Это: - данные о продуктовом поведении покупателя и коммуникациях с ним; - данные о выручке с покупателя; - данные о времени провденном покупателем на сайте и - данные о среднемесячной прибыли с покупателя.
# Из исходных данных были сформированы 3 датафрейма, данные были очищены от дубликатов. На их основе был сформирован итоговый датафрейм - датасет "Объединенные данные о покупателях', 1296 записей.
#
# Прооведен анализ распределения параметров.
#
# В ходе корелляционого анализа данных с помошью коэффициента корреляции Фи было выяснено что для целевого признака "покупательская активность" наибольшая корреляция установлена с признаками - "маркет актив 6 мес", "акционные покупки", "средний просмотр категорий за визит", "неоплаченные продукты штук квартал", "страниц за визит", "выручка_препред", "время_пред" и "время_тек". Cильно связаны "выручка в текущем месяце" и "выручка в прошлом месяце", вероятно у них близкие значения.
#
# Для построения модели предсказания целевого параметра методом перебора был осуществлен поиск оптимальной модели, из четырех типов была выбрана наиболее оптимальная с помощью пайплайна. В результате лучшей моделью была признана модель построенная методом опорных векторов. Метрика ROC_AUC составила 0,908.
#
# Значения параметров для модели значимые - "страниц_за_визит" - кол-во просмотренных страниц за визит и "время_пред", "время_тек"(проведенного на сайте времени за предыдущий и текущий месяцы) , "акционные_покупки"- число товаров купленных по акции, "средний_просмотр_категорий_за_визит" следующие по значимости, затем идут "неоплаченные_покупки_штвквартал", "маркет_актив_6мес" - маркетинговая активность за 6 месяцев, "выручка_предпред" - выручка за препредыдущий месяц.
# Высокие значения "страниц_за_визит" и "время_пред", "время_тек"(проведенного на сайте времени) уменьшают вероятность отнесения клиента к категории - "Покупательская_активнось" снизилась.
#
# Для признаков "акционные_покупки" и "неоплаченные_продукты_штук_квартал" ситуация обратная - чем выше значение этих параметров, тем больше вероятность, что клиент станет меньше покупать в интернет-магазине. Поэтому необходимо направить маркетинговое внимание на клиентов покупающих товар по акции.
#
# Кроме того, выявлено значительное количество ошибок сайта - необходимо поработать на качеством сервиса.
